# %% [markdown]
# <a href="https://colab.research.google.com/github/gangpopo/ai/blob/main/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.DataFrame({'name':['강하람','이원준','김동현'],'hobby':['축구보기','넷플릭스','공연보기'],'nationality':['한국','한국','한국']})

# %%
df.set_index(keys='name',inplace=True)

# %%
df
# Out:
#      hobby nationality
# name
# 강하람   축구보기          한국
# 이원준   넷플릭스          한국
# 김동현   공연보기          한국

# %%
df.to_csv(r"week2.csv",)

# %%
pd.read_csv(r'/content/week2.csv')
# Out:
#   name hobby nationality
# 0  강하람  축구보기          한국
# 1  이원준  넷플릭스          한국
# 2  김동현  공연보기          한국
